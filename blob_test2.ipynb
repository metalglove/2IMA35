# %%
from utils.GraphGenerator import GraphGenerator
from utils.datasets import generate_points
from utils.RunningUtils import do_boruvka_on_graph

points = generate_points('blobs', n_samples=500, n_clusters=3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from utils.GraphGenerator import GraphGenerator
#       2 from utils.datasets import generate_points
# ----> 3 from utils.RunningUtils import do_boruvka_on_graph
#       5 points = generate_points('blobs', n_samples=500, n_clusters=3)
#
# File c:\Projects\mpa\utils\RunningUtils.py:1
# ----> 1 from GraphVisualizer import GraphVisualizer
#       2 from algorithms.BoruvkasAlgorithm import BoruvkasAlgorithm
#       4 def do_boruvka_on_graph(graph, graph_name, iterations = 10):
#
# ModuleNotFoundError: No module named 'GraphVisualizer'

# %%
G = GraphGenerator(points.copy()) \
    .to_graph(gen_pair_wise=True)

do_boruvka_on_graph(G, "Blobs graph")
# Out:
# running boruvkas algorithm: max_iterations = 10
# Graph:
# round 1
# ...

# %%
G_line = GraphGenerator(points.copy()) \
    .draw_line((-1, 3.5), (0, -5.5), 0.2) \
    .to_graph(gen_pair_wise=True)

do_boruvka_on_graph(G_line, "Blobs graph with pingas xd")
# Out:
# running boruvkas algorithm: max_iterations = 10
# Graph:
# round 1
# ...
