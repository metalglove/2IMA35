# %%
from utils.GraphGenerator import GraphGenerator
from utils.GraphVisualizer import GraphVisualizer
from utils.datasets import generate_points

points = generate_points('ans1a')

# %%
from algorithms.BoruvkasAlgorithm import BoruvkasAlgorithm

def run(points):
    G = GraphGenerator(points.copy()) \
        .to_graph(gen_pair_wise=True)

    gv = GraphVisualizer(G)
    gv.plot_graph('Graph')

    max_iterations = 10
    plot_graph = lambda i: gv.plot_graph(f'Graph boruvkas round {i}')
    alg = BoruvkasAlgorithm(G, max_iterations, False, plot_graph)
    _ = alg.run()

# %%
run(points)
# Out:
# running boruvkas algorithm: max_iterations = 10
# Graph:
# round 1
# neighborhoods: ['(12, {0, 1, 2, 3, 4, 5, 6, 7, 11, 12, 13}) ', '(9, {8, 9, 10}) ', '(14, {14, 15}) ', '(32, {32, 33, 34, 16, 18, 20, 22, 24, 26, 30, 31}) ', '(28, {17, 19, 21, 23, 25, 27, 28, 29}) ', '(35, {35, 36}) ', '(39, {37, 38, 39, 40}) ', '(41, {41, 42}) ', '(45, {43, 44, 45, 46}) ']
# round 2
# neighborhoods: ['(9, {9, 12, 14}) ', '(28, {32, 28}) ', '(41, {35, 39, 41, 45}) ']
# round 3
# final neighborhood: (28, {9, 28, 41})

# %%
points.sort()
run(points)
# Out:
# running boruvkas algorithm: max_iterations = 10
# Graph:
# round 1
# neighborhoods: ['(30, {0, 1, 3, 4, 8, 9, 13, 14, 20, 21, 22, 23, 27, 28, 29, 30, 31}) ', '(33, {2, 5, 6, 7, 10, 11, 12, 15, 16, 17, 24, 25, 26, 32, 33, 34}) ', '(18, {18, 19}) ', '(35, {35, 36}) ', '(41, {37, 39, 41, 43}) ', '(42, {38, 40, 42, 44}) ', '(45, {45, 46}) ']
# round 2
# neighborhoods: ['(18, {33, 18, 30}) ', '(42, {35, 41, 42, 45}) ']
# round 3
# final neighborhood: (18, {18, 42})
