# %%
from algorithms.BoruvkasAlgorithm import BoruvkasAlgorithm
from utils.GraphUtils import generate_graph, generate_plot_for_graph, plot_graph
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons

# %%
import math

n_samples = 1500
V, y = make_moons(n_samples=n_samples, noise=0.00, random_state=56)

points = V

weightCalculation = lambda p1, p2: math.ceil(math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2))
Gmewns1 = generate_graph(points, weightCalculation)

generate_plot_for_graph(Gmewns1)

# %%
max_iterations = 10
alg = BoruvkasAlgorithm(Gmewns1, max_iterations)
L, Vs, Es = alg.run()
# Out:
# running boruvkas algorithm: max_iterations = 10
# Graph:
# round 1
# ...

# %%
n = len(Vs)
fig, axarr = plt.subplots(2, 2, sharex='all', sharey='all')
for ax, i in zip(axarr.ravel(), range(len(axarr) + 1)):
    V = Vs[i]
    E = Es[i]
    plot_graph(V, E, points, ax)
